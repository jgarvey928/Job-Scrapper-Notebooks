# %% [markdown]
# <a href="https://colab.research.google.com/github/jgarvey928/Colab_Notebooks/blob/main/Test_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
i = 0
while i < 5:
    print("test")
    i+=1
# Out:
# test
# test
# test
# test
# test
